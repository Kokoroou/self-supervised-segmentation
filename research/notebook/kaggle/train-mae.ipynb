# %%
# Change these variable to start training
CHECKPOINT_URL = "https://dl.fbaipublicfiles.com/mae/visualize/mae_visualize_vit_base.pth"
ARCHITECTURE = "mae_vit_base_patch16"
SOURCE_DIR = "/kaggle/input/polypgen2021-autoencoder/PolypGen2021_autoencoder/train_autoencoder"
EPOCHS = 100

# %% [markdown]
# # Initialize

# %%
import os


# Set working directory
os.chdir("/kaggle/working")

# %%
# !cd ./ && pwd && ls

# %% [markdown]
# # Get code from Github

# %%
# Config
repo_url = "https://github.com/Kokoroou/self-supervised-segmentation"
repo_dir = "./main"

# %%
# Download repo from Github
# !git clone {repo_url} {repo_dir}

# %% [markdown]
# # Training

# %%
import wandb
from kaggle_secrets import UserSecretsClient


user_secrets = UserSecretsClient()
wandb_api_key = user_secrets.get_secret("wandb_api_key")
wandb.login(key=wandb_api_key)

# %%
# !pip install imutils
# !pip install wget
# !pip install validators

# %%
import time
import wget


# Download checkpoint directly from kernel to reduce time between resumings
checkpoint_dir = "./checkpoint/"
checkpoint_name = "last.pth"
checkpoint_path = checkpoint_dir + checkpoint_name

os.makedirs(checkpoint_dir, exist_ok=True)

if not os.path.exists(checkpoint_path):
    start = time.time()
    print("\nDownloading last checkpoint...")
    wget.download(CHECKPOINT_URL, checkpoint_path)
    print("\nDownloaded last checkpoint in {}s".format(round(time.time() - start, 3)))

# %%
# !python {repo_dir}/research/main_autoencoder.py train -m mae -a {ARCHITECTURE} --from-pretrained -c {checkpoint_path} -s {SOURCE_DIR} -o {checkpoint_dir} --epochs {EPOCHS} --wandb

# %%
# Reduce consumed GPU Memory when stop training in the middle of process
import gc
import torch

gc.collect()
torch.cuda.empty_cache()
